# %%
import pandas as pd
from functions.display_plots import FeatureVisualizer
from functions.feature_stats import FeatureStats
from functions.feature_relations import FeatureRelations
from functions.eda_dataset import EdaDataset

# %% [markdown]
# # I. Mean Features
# ### Overview of Mean-based Measurements

# %%
subset_mean = pd.read_csv('../data/subsets_preprocessed/subset_mean.csv')
subset_mean
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
subset_mean.drop(columns=['diagnosis']).describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
# Values: 0: Benign; 1: Malignant
subset_mean['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
features = subset_mean.columns.drop('diagnosis')
features
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean'],
#       dtype='object')

# %%
feature_analyze = EdaDataset(dataset=subset_mean, target_column='diagnosis')
for feature in features:
    feature_analyze.analyze_feature(feature)
# Out:
# ## Analyzing **radius_mean**
# ### Distribution **radius_mean**
# ### Statistical analysis with Boxplot and t-test **radius_mean**
#        Feature  t-statistic       p-value
# 0  radius_mean   -25.435822  8.465941e-96
# ## Analyzing **texture_mean**
# ### Distribution **texture_mean**
# ### Statistical analysis with Boxplot and t-test **texture_mean**
#         Feature  t-statistic       p-value
# 0  texture_mean   -10.867201  4.058636e-25
# ## Analyzing **perimeter_mean**
# ### Distribution **perimeter_mean**
# ### Statistical analysis with Boxplot and t-test **perimeter_mean**
#           Feature  t-statistic        p-value
# 0  perimeter_mean   -26.405213  8.436251e-101
# ## Analyzing **area_mean**
# ### Distribution **area_mean**
# ### Statistical analysis with Boxplot and t-test **area_mean**
#      Feature  t-statistic       p-value
# 0  area_mean   -23.938687  4.734564e-88
# ## Analyzing **smoothness_mean**
# ### Distribution **smoothness_mean**
# ...

# %%
feature_relations = FeatureRelations(dataset=subset_mean)
feature_relations.show_confusion_metrix()
