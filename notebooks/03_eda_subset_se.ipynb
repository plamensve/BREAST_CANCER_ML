# %%
import pandas as pd
from functions.display_plots import FeatureVisualizer
from functions.feature_stats import FeatureStats
from functions.feature_relations import FeatureRelations
from functions.eda_dataset import EdaDataset

# %%
subset_se = pd.read_csv('../data/subsets_preprocessed/subset_se.csv')
subset_se
# Out:
#      diagnosis  radius_se  texture_se  perimeter_se  area_se  smoothness_se  \
# 0            1     1.0950      0.9053         8.589   153.40       0.006399
# 1            1     0.5435      0.7339         3.398    74.08       0.005225
# 2            1     0.7456      0.7869         4.585    94.03       0.006150
# 3            1     0.4956      1.1560         3.445    27.23       0.009110
# 4            1     0.7572      0.7813         5.438    94.44       0.011490
# ..         ...        ...         ...           ...      ...            ...
# 564          1     1.1760      1.2560         7.673   158.70       0.010300
# 565          1     0.7655      2.4630         5.203    99.04       0.005769
# 566          1     0.4564      1.0750         3.425    48.55       0.005903
# 567          1     0.7260      1.5950         5.772    86.22       0.006522
# 568          0     0.3857      1.4280         2.548    19.15       0.007189
#
# ...

# %%
subset_se.drop(columns=['diagnosis']).describe()
# Out:
#         radius_se  texture_se  perimeter_se     area_se  smoothness_se  \
# count  569.000000  569.000000    569.000000  569.000000     569.000000
# mean     0.405172    1.216853      2.866059   40.337079       0.007041
# std      0.277313    0.551648      2.021855   45.491006       0.003003
# min      0.111500    0.360200      0.757000    6.802000       0.001713
# 25%      0.232400    0.833900      1.606000   17.850000       0.005169
# 50%      0.324200    1.108000      2.287000   24.530000       0.006380
# 75%      0.478900    1.474000      3.357000   45.190000       0.008146
# max      2.873000    4.885000     21.980000  542.200000       0.031130
#
#        compactness_se  concavity_se  concave_points_se  symmetry_se  \
# count      569.000000    569.000000         569.000000   569.000000
# mean         0.025478      0.031894           0.011796     0.020542
# std          0.017908      0.030186           0.006170     0.008266
# ...

# %%
# Values: 0: Benign; 1: Malignant
subset_se['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
features = subset_se.columns.drop('diagnosis')
features
# Out:
# Index(['radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se'],
#       dtype='object')

# %%
feature_analyze = EdaDataset(dataset=subset_se, target_column='diagnosis')
for feature in features:
    feature_analyze.analyze_feature(feature)
# Out:
# ## Analyzing **radius_se**
# ### Distribution **radius_se**
# ### Statistical analysis with Boxplot and t-test **radius_se**
#      Feature  t-statistic       p-value
# 0  radius_se   -16.396351  9.738949e-50
# ## Analyzing **texture_se**
# ### Distribution **texture_se**
# ### Statistical analysis with Boxplot and t-test **texture_se**
#       Feature  t-statistic   p-value
# 0  texture_se     0.197724  0.843332
# ## Analyzing **perimeter_se**
# ### Distribution **perimeter_se**
# ### Statistical analysis with Boxplot and t-test **perimeter_se**
#         Feature  t-statistic       p-value
# 0  perimeter_se   -15.934158  1.651905e-47
# ## Analyzing **area_se**
# ### Distribution **area_se**
# ### Statistical analysis with Boxplot and t-test **area_se**
#    Feature  t-statistic       p-value
# 0  area_se   -15.609343  5.895521e-46
# ## Analyzing **smoothness_se**
# ### Distribution **smoothness_se**
# ### Statistical analysis with Boxplot and t-test **smoothness_se**
# ...

# %%
feature_relations = FeatureRelations(dataset=subset_se)
feature_relations.show_confusion_metrix()
