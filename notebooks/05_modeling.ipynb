# %%
from sklearn import svm
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('../data/preprocessed_data/p_data.csv')
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
X = data.drop(columns='diagnosis')
y = data['diagnosis']

scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)

X_train, X_test, y_train, y_test, = train_test_split(
    X_scaler, y, test_size=0.2, random_state=42, stratify=y
)

clf = svm.SVC(kernel='linear', C=0.1, gamma='scale', class_weight={0:1, 1:3})
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# confusion matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=['Benign (0)', 'Malignant (1)'],
            yticklabels=['Benign (0)', 'Malignant (1)'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - SVM (RBF kernel)")
plt.show()
# Out:
# Accuracy: 0.9824561403508771
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        72
#            1       0.98      0.98      0.98        42
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
coefficients = clf.coef_[0]
feature_names = data.drop(columns='diagnosis').columns

feat_importance = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients,
    'Absolute_Importance': np.abs(coefficients)
}).sort_values(by='Absolute_Importance', ascending=False)

top_features = feat_importance.head(30)

plt.figure(figsize=(12,10))
plt.barh(
    top_features['Feature'], 
    top_features['Absolute_Importance'], 
    color='skyblue', 
    edgecolor='k'
    )

plt.gca().invert_yaxis()
plt.title("Importance of features - SVM [Linear Kernel]")
plt.xlabel("Absolute Importance [Coefficient]")
plt.ylabel("Feature")

for i, v in enumerate(top_features['Absolute_Importance']):
    plt.text(v + 0.01, i, f"{v:.2f}", va='center')

plt.show()

# %%
from sklearn.pipeline import make_pipeline

model = make_pipeline(
    StandardScaler(),
    SVC(kernel="linear", C=0.1)
)

scores = cross_val_score(model, X, y, cv=5, scoring="recall")

print("Avg. result from CV:", scores.mean())
print("Results by folds:", scores)
# Out:
# Avg. result from CV: 0.9481727574750831
# Results by folds: [0.95348837 0.93023256 0.95238095 0.92857143 0.97619048]

# %%
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    data[data['diagnosis']==0]['texture_worst'],
    data[data['diagnosis']==0]['radius_se'],
    color='blue', label='Benign (0)', edgecolors='k'
)

plt.scatter(
    data[data['diagnosis']==1]['texture_worst'],
    data[data['diagnosis']==1]['radius_se'],
    color='red', label='Malignant (1)', edgecolors='k'
)

plt.xlabel("texture_worst")
plt.ylabel("radius_se")
plt.title("Scatterplot: Radius vs Texture (with legend)")
plt.legend()
plt.show()
