# %%
import pandas as pd
from functions.display_plots import FeatureVisualizer
from functions.feature_stats import FeatureStats
from functions.feature_relations import FeatureRelations
from functions.eda_dataset import EdaDataset

# %%
subset_worst = pd.read_csv('../data/subsets_preprocessed/subset_worst.csv')
subset_worst
# Out:
#      diagnosis  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0            1        25.380          17.33           184.60      2019.0
# 1            1        24.990          23.41           158.80      1956.0
# 2            1        23.570          25.53           152.50      1709.0
# 3            1        14.910          26.50            98.87       567.7
# 4            1        22.540          16.67           152.20      1575.0
# ..         ...           ...            ...              ...         ...
# 564          1        25.450          26.40           166.10      2027.0
# 565          1        23.690          38.25           155.00      1731.0
# 566          1        18.980          34.12           126.70      1124.0
# 567          1        25.740          39.42           184.60      1821.0
# 568          0         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# ...

# %%
subset_worst.drop(columns=['diagnosis']).describe()
# Out:
#        radius_worst  texture_worst  perimeter_worst   area_worst  \
# count    569.000000     569.000000       569.000000   569.000000
# mean      16.269190      25.677223       107.261213   880.583128
# std        4.833242       6.146258        33.602542   569.356993
# min        7.930000      12.020000        50.410000   185.200000
# 25%       13.010000      21.080000        84.110000   515.300000
# 50%       14.970000      25.410000        97.660000   686.500000
# 75%       18.790000      29.720000       125.400000  1084.000000
# max       36.040000      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# ...

# %%
# Values: 0: Benign; 1: Malignant
subset_worst['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
features = subset_worst.columns.drop('diagnosis')
features
# Out:
# Index(['radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
feature_analyze = EdaDataset(dataset=subset_worst, target_column='diagnosis')
for feature in features:
    feature_analyze.analyze_feature(feature)
# Out:
# ## Analyzing **radius_worst**
# ### Distribution **radius_worst**
# ### Statistical analysis with Boxplot and t-test **radius_worst**
#         Feature  t-statistic        p-value
# 0  radius_worst   -29.339082  8.482292e-116
# ## Analyzing **texture_worst**
# ### Distribution **texture_worst**
# ### Statistical analysis with Boxplot and t-test **texture_worst**
#          Feature  t-statistic       p-value
# 0  texture_worst   -12.230981  1.078057e-30
# ## Analyzing **perimeter_worst**
# ### Distribution **perimeter_worst**
# ### Statistical analysis with Boxplot and t-test **perimeter_worst**
#            Feature  t-statistic        p-value
# 0  perimeter_worst   -29.965717  5.771397e-119
# ## Analyzing **area_worst**
# ### Distribution **area_worst**
# ### Statistical analysis with Boxplot and t-test **area_worst**
#       Feature  t-statistic       p-value
# 0  area_worst    -25.72159  2.828848e-97
# ## Analyzing **smoothness_worst**
# ### Distribution **smoothness_worst**
# ...

# %%
feature_relations = FeatureRelations(dataset=subset_worst)
feature_relations.show_confusion_metrix()
